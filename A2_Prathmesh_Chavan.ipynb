# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
dic_info = {"name":"Paras","Age":25,"City":"Pune"}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
Age = dic_info["Age"]
print(Age)
# Out:
# 25

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
per_info = {"name":"Paras","Age":25,"City":"Pune"}

# %%
per_info["Occupation"] = "Engineer"
print(per_info)
# Out:
# {'name': 'Paras', 'Age': 25, 'City': 'Pune', 'Occupation': 'Engineer'}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
per_info
# Out:
# {'name': 'Paras', 'Age': 25, 'City': 'Pune', 'Occupation': 'Engineer'}

# %%
per_info["Age"] = 30
print(per_info)
# Out:
# {'name': 'Paras', 'Age': 30, 'City': 'Pune', 'Occupation': 'Engineer'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
car_info = {"Brand":"xyz","Model":"LXI","Fuel":"Diesel"}

# %%
car_info.pop("Model")
print(car_info)
# Out:
# {'Brand': 'xyz', 'Fuel': 'Diesel'}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
car_info = {"Brand":"xyz","Model":"LXI","Fuel":"Diesel"}
car_info["Origin"]="German"
print(car_info)
# Out:
# {'Brand': 'xyz', 'Model': 'LXI', 'Fuel': 'Diesel', 'Origin': 'German'}

# %%
car_info.popitem()
# Out:
# ('Origin', 'German')

# %%
car_info
# Out:
# {'Brand': 'xyz', 'Model': 'LXI', 'Fuel': 'Diesel'}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
car_info = {'Brand': 'xyz', 'Model': 'LXI', 'Fuel': 'Diesel', 'Origin': 'German'}

# %%
print(car_info.keys())
# Out:
# dict_keys(['Brand', 'Model', 'Fuel', 'Origin'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
print(car_info.values())
# Out:
# dict_values(['xyz', 'LXI', 'Diesel', 'German'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
car_info
# Out:
# {'Brand': 'xyz', 'Model': 'LXI', 'Fuel': 'Diesel', 'Origin': 'German'}

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
car_info = {'Brand': 'xyz', 'Model': 'LXI', 'Fuel': 'Diesel', 'Origin': 'German'}

# %%
print(len(car_info))
# Out:
# 4

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
car_info = {'Brand': 'xyz', 'Model': 'LXI', 'Fuel': 'Diesel', 'Origin': 'German'}

# %%
print("Fuel" in car_info)
# Out:
# True

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
emp_dic = {}

# %%
emp_dic["Name"] = "rahul"
emp_dic["Age"] = 20
print(emp_dic)
# Out:
# {'Name': 'rahul', 'Age': 20}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
det = {'Name': 'rahul', 'Age': 20}

# %%
det.update({"Age": 34})
print(det)
# Out:
# {'Name': 'rahul', 'Age': 34}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
cv_dic = {'Name': 'rahul', 'Age': 20}

# %%
cv_dic.update({"Country": "Australia", "Occ":"Job person"})

# %%
print(cv_dic)
# Out:
# {'Name': 'rahul', 'Age': 20, 'Country': 'Australia', 'Occ': 'Job person'}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
vv_dic = {'Name': 'rahul', 'Age': 20, 'Country': 'Australia', 'Occ': 'Job person'}
print(vv_dic.values())
# Out:
# dict_values(['rahul', 20, 'Australia', 'Job person'])

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
type(vv_dic)
# Out:
# dict

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
vv_dic = {'Name': 'rahul', 'Age': 20, 'Country': 'Australia', 'Occ': 'Job person'}

# %%
vv_dic["Country"] = "India"
print(vv_dic)
# Out:
# {'Name': 'rahul', 'Age': 20, 'Country': 'India', 'Occ': 'Job person'}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
clear_dic = {'Name': 'rahul', 'Age': 20, 'Country': 'Australia', 'Occ': 'Job person'}

# %%
clear_dic.clear()

# %%
print(clear_dic)
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
nv_dic = {20 : "YFM", 15 :"Mileage", 1000:"Units" }

# %%
print(nv_dic)
# Out:
# {20: 'YFM', 15: 'Mileage', 1000: 'Units'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
nv_dic = {20 : "YFM", 15 :"Mileage", 1000:"Units" }

# %%
lv_dic = nv_dic.copy()
print(lv_dic)
# Out:
# {20: 'YFM', 15: 'Mileage', 1000: 'Units'}
